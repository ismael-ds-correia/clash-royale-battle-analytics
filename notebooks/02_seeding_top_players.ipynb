# %%
import requests
import json

TOKEN = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..SgSfiZuZTI34n7rQOT4NHUdfhsikx1d8ItXBLJVZThBgD1SebYbEpHVLU-a1UaaCX2Vbn6Z_mFAmNGwxlL8QbQ"
season_id = "2026-01"
limit = 200

# Endpoint para ranking de jogadores da temporada
url = f"https://api.clashroyale.com/v1/locations/global/pathoflegend/{season_id}/rankings/players"
headers = {"Authorization": f"Bearer {TOKEN}"}

players = []
after = None

while len(players) < 1000:
    params = {"limit": limit}
    if after:
        params["after"] = after
    response = requests.get(url, headers=headers, params=params)
    data = response.json()
    players.extend(data.get("items", []))
    after = data.get("paging", {}).get("cursors", {}).get("after")
    if not after or len(players) >= 1000:
        break

with open(f'../data/pathoflegend_{season_id}_top1000.json', 'w', encoding='utf-8') as f:
    json.dump(players[:1000], f, ensure_ascii=False, indent=2)

print(f"Salvo ../data/pathoflegend_{season_id}_top1000.json com {len(players[:1000])} jogadores.")
# Out:
# Salvo ../data/pathoflegend_2026-01_top1000.json com 1000 jogadores.
