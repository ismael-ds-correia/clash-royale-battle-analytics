# %%
import requests

# Token de acesso
TOKEN = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..Bt2mg-k0ydnZeLi1oV0gXpA-enRqZ3O_NWoDeVFVL5CkUiww_SOQ0zShmpI3KXLTg_6b-uv_4sipr9ibhyqeWQ"

# Endpoint da temporadas
url = "https://api.clashroyale.com/v1/locations/global/seasons"
headers = {"Authorization": f"Bearer {TOKEN}"}

response = requests.get(url, headers=headers)
print(response.json())
# Out:
# {'items': [{'id': '2016-02'}, {'id': '2016-02'}, {'id': '2016-03'}, {'id': '2016-03'}, {'id': '2016-04'}, {'id': '2016-04'}, {'id': '2016-05'}, {'id': '2016-05'}, {'id': '2016-05'}, {'id': '2016-06'}, {'id': '2016-06'}, {'id': '2016-07'}, {'id': '2016-07'}, {'id': '2016-08'}, {'id': '2016-08'}, {'id': '2016-09'}, {'id': '2016-09'}, {'id': '2016-10'}, {'id': '2016-10'}, {'id': '2016-10'}, {'id': '2016-11'}, {'id': '2016-11'}, {'id': '2016-12'}, {'id': '2016-12'}, {'id': '2017-01'}, {'id': '2017-01'}, {'id': '2017-02'}, {'id': '2017-02'}, {'id': '2017-03'}, {'id': '2017-03'}, {'id': '2017-04'}, {'id': '2017-05'}, {'id': '2017-06'}, {'id': '2017-07'}, {'id': '2017-08'}, {'id': '2017-09'}, {'id': '2017-10'}, {'id': '2017-11'}, {'id': '2017-12'}, {'id': '2018-01'}, {'id': '2018-02'}, {'id': '2018-03'}, {'id': '2018-04'}, {'id': '2018-05'}, {'id': '2018-06'}, {'id': '2018-07'}, {'id': '2018-08'}, {'id': '2018-09'}, {'id': '2018-10'}, {'id': '2018-11'}, {'id': '2018-12'}, {'id': '2019-01'},
# ...

# %%
import pandas as pd

data = response.json()

season_ids = [item['id'] for item in data['items'] if item.get('id')]

# Removendo duplicatas
season_ids_unique = list(dict.fromkeys(season_ids))
season_ids_unique.reverse()

df = pd.DataFrame(season_ids_unique, columns=['season_id'])
df.to_csv('../data/season_ids.csv', index=False)

print(df.head())
# Out:
#   season_id
# 0   2026-01
# 1   2025-12
# 2   2025-11
# 3   2025-10
# 4   2025-09
